# %% [markdown]
# <a href="https://colab.research.google.com/github/LucyMariel/Lucy/blob/master/DIVICDummydata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **[Problem 1] Creating random numbers**
#
# Create 500 random numbers with a two-dimensional normal distribution whose mean is (-3, 0) and whose covariance matrix is 1.0
# 0.8
# 0.8
# 1.0
# . Multidimensional normally distributed random numbers can be created by using np.random.multivariate_normal() .
# numpy.random.multivariate_normal — NumPy v1.19 Manual
#
# The shape of the created ndarray will be (500, 2).
#
# <Seed value>
#
# To ensure that the value does not change from one run to the next, we will fix the seed value of the random number using np.random.seed() . We will use a seed value of 0.

# %%
import numpy as np
# Set the seed value for reproducibility
np.random.seed(0)

mean = (-3, 0)
cov = [[1.0, 0.8], [0.8, 1.0]]

# Generate 500 random numbers with a two-dimensional normal distribution
x = np.random.multivariate_normal(mean, cov, 500)

# Print the shape to confirm it's (500, 2)
print(x.shape)
# Out:
# (500, 2)

# %% [markdown]
# **[Problem 2] Visualization by scatter plot**
#
# Visualize the data points created in Problem 1 with a scatter plot.
#
# Scatter plots can be drawn by using matplotlib's plt.scatter()

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:, 0], x[:, 1])
plt.title("Scatter plot of 500 random numbers with 2D normal distribution")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()

# %% [markdown]
# **[Problem 3] Visualization by histogram**
# Visualize the data created in Problem 1 with a histogram.
#
# A histogram can be drawn by using plt.hist() .
#
# matplotlib.pyplot.hist — Matplotlib 3.1.1 documentation
#
# Create it for each dimension and create two histograms.
#
# The range of the horizontal axis of each histogram should be aligned using plt.xlim() .
#
# matplotlib.pyplot.xlim — Matplotlib 3.1.1 documentation

# %%
import pandas as pd
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Plot histograms for each dimension
ax[0].hist(x[:, 0], bins=30, alpha=0.7, color='blue', edgecolor='black')
ax[0].set_title("Histogram of X1")
ax[0].set_xlabel("X1")
ax[0].set_ylabel("Frequency")

ax[1].hist(x[:, 1], bins=30, alpha=0.7, color='green', edgecolor='black')
ax[1].set_title("Histogram of X2")
ax[1].set_xlabel("X2")
ax[1].set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **[Problem 4] Addition of data**
#
# Create 500 new random numbers with a two-dimensional normal distribution whose mean is (0, -3) and whose covariance matrix is represented by the following.
#
# [
# 1.0
# 0.8
# 0.8
# 1.0
# ]
# Then, visualize the data of problems 1 and 4 as one scatter plot. As a legend, show 0for Problem 1 and1for Problem 4.

# %%
# Set the seed value for reproducibility
np.random.seed(0)

mean = (0, -3)
cov = [[1.0, 0.8], [0.8, 1.0]]

# Generate 500 random numbers with a two-dimensional normal distribution
y = np.random.multivariate_normal(mean, cov, 500)

# Print the shape to confirm it's (500, 2)
print(y.shape)
# Out:
# (500, 2)

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x[:, 0], x[:, 1], alpha=0.5, label='Mean (-3, 0)', color='blue')
plt.scatter(y[:, 0], y[:, 1], alpha=0.5, label='Mean (0, -3)', color='red')
plt.title("Scatter plot of 500 random numbers with different 2D normal distributions")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()

# %% [markdown]
# **[Problem 5] Data combination**
#
# It is better to keep the data together so that it is easier to deal with later. Combine the ndarrays created in Problems 1 and 4 into  a single ndarray of (1000, 2). The concatenation can be done using np.concatenate() or  np.vstack() .
#
# numpy.concatenate — NumPy v1.19 Manual
#
# numpy.vstack — NumPy v1.19 Manual

# %%
df = np.concatenate([x, y], axis=0) #row direction
df.shape
# Out:
# (1000, 2)

# %% [markdown]
# **[Problem 6] Labeling**
#
# For each of the 1000 pieces of data that you have combined together, label them to indicate whether they are from question 1 or 4. Question 1 should be labeled 0 and Question 4 should be labeled 1 .
#
# Create a ndarray of (1000, 3) by adding a new column of labels containing 0s and 1s.
#
# Datasets used for machine learning often have this form.
#
# << Creation example >>
#
# When there are 3 + 3 data, the ndarray is (6, 3) as below.

# %%
import numpy as np

# Set the seed value for reproducibility for the first set
np.random.seed(0)

# Define the first mean and covariance matrix
mean1 = [-3, 0]
cov1 = [[1.0, 0.8], [0.8, 1.0]]

# Generate the first set of 500 random numbers with a two-dimensional normal distribution
x = np.random.multivariate_normal(mean1, cov1, 500)

# Set the seed value for reproducibility for the second set
np.random.seed(0)

# Define the second mean and covariance matrix
mean2 = [0, -3]
cov2 = [[1.0, 0.8], [0.8, 1.0]]

# Generate the second set of 500 random numbers with a two-dimensional normal distribution
y = np.random.multivariate_normal(mean2, cov2, 500)

# Concatenate the two datasets
df = np.concatenate([x, y], axis=0)

# Create the labels
labels = np.concatenate([np.zeros(500), np.ones(500)])

# Combine the data and labels into a single ndarray
df_with_labels = np.column_stack((df, labels))

# Print the shape to confirm it's (1000, 3)
print(df_with_labels.shape)

# Display the first few rows to check
print(df_with_labels[:10])
# Out:
# (1000, 3)
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  [-3.85346966 -0.94919637  0.        ]
#  [-3.03192065  0.22776465  0.        ]
#  [-3.59653339  0.32322993  0.        ]
#  [-3.7604608  -0.68350676  0.        ]
#  [-3.52660272 -0.31556855  0.        ]
#  [-4.35253112 -1.4822846   0.        ]
#  [-3.02691331 -0.56709089  0.        ]]
