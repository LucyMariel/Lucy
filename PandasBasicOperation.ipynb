# %% [markdown]
# <a href="https://colab.research.google.com/github/LucyMariel/Lucy/blob/master/PandasBasicOperation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
row = pd.Series([10, 20, 30, 40, 50])
row
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
row = pd.Series(["A, B, C, D, E"])
row
# Out:
# 0    A, B, C, D, E
# dtype: object

# %%
row = pd.Series(["A", "B", "C", "D", "E"])
row
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %%
row = row.astype(str)
print(row)
row.dtype
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object
# dtype('O')

# %%
print(row.dtype)
# Out:
# object

# %%
df = pd.DataFrame([[10, "ten", True],
                   [20, "twenty", False],
                   [30, "thirty", True],
                   [40, "forty", False],
                   [50, "fifty", False]])
df
# Out:
#     0       1      2
# 0  10     ten   True
# 1  20  twenty  False
# 2  30  thirty   True
# 3  40   forty  False
# 4  50   fifty  False

# %%
#How use Numpy in Pandas

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.arange(100).reshape((20, 5)))
df
# Out:
#      0   1   2   3   4
# 0    0   1   2   3   4
# 1    5   6   7   8   9
# 2   10  11  12  13  14
# 3   15  16  17  18  19
# 4   20  21  22  23  24
# 5   25  26  27  28  29
# 6   30  31  32  33  34
# 7   35  36  37  38  39
# 8   40  41  42  43  44
# 9   45  46  47  48  49
# 10  50  51  52  53  54
# 11  55  56  57  58  59
# 12  60  61  62  63  64
# 13  65  66  67  68  69
# 14  70  71  72  73  74
# 15  75  76  77  78  79
# 16  80  81  82  83  84
# 17  85  86  87  88  89
# 18  90  91  92  93  94
# 19  95  96  97  98  99

# %%
df.head()
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %%
df.head(10)
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# 5  25  26  27  28  29
# 6  30  31  32  33  34
# 7  35  36  37  38  39
# 8  40  41  42  43  44
# 9  45  46  47  48  49

# %%
df.tail(5)
# Out:
#      0   1   2   3   4
# 15  75  76  77  78  79
# 16  80  81  82  83  84
# 17  85  86  87  88  89
# 18  90  91  92  93  94
# 19  95  96  97  98  99

# %%
df.shape
# Out:
# (20, 5)

# %%
df = pd.DataFrame(np.arange(9).reshape((3, 3)))
df
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df.index = ["1st line", "2nd line", "3rd line"]
df.columns = ["column A", "column B", "column C"]

# %%
df
# Out:
#           column A  column B  column C
# 1st line         0         1         2
# 2nd line         3         4         5
# 3rd line         6         7         8

# %%
#Dictionary form
pd.DataFrame({"column A": [1, 2, 3], "column B": [10, 20, 30], "column C": [True, False, False]})
# Out:
#    column A  column B  column C
# 0         1        10      True
# 1         2        20     False
# 2         3        30     False

# %% [markdown]
# For extract from DataFrame

# %%
df = pd.DataFrame(np.arange(20).reshape((5, 4)),
                  index=["1st line", "2nd line", "3rd line", "4th line", "5th line"],
                  columns=["column A", "column B", "column C", "Column D"])
df
# Out:
#           column A  column B  column C  Column D
# 1st line         0         1         2         3
# 2nd line         4         5         6         7
# 3rd line         8         9        10        11
# 4th line        12        13        14        15
# 5th line        16        17        18        19

# %%
df["column A"]
# Out:
# 1st line     0
# 2nd line     4
# 3rd line     8
# 4th line    12
# 5th line    16
# Name: column A, dtype: int64

# %%
df[["column A", "column C"]]
# Out:
#           column A  column C
# 1st line         0         2
# 2nd line         4         6
# 3rd line         8        10
# 4th line        12        14
# 5th line        16        18

# %%
df[:"1st line"]
# Out:
#           column A  column B  column C  Column D
# 1st line         0         1         2         3

# %%
df[:1]
# Out:
#           column A  column B  column C  Column D
# 1st line         0         1         2         3

# %%
df["3rd line":"3rd line"]
# Out:
#           column A  column B  column C  Column D
# 3rd line         8         9        10        11

# %%
df = pd.DataFrame(np.arange(20).reshape((5, 4)),
                  index=["1st line", "2nd line", "3rd line", "4th line", "5th line"],
                  columns=["column A", "column B", "column C", "Column D"])
df
# Out:
#           column A  column B  column C  Column D
# 1st line         0         1         2         3
# 2nd line         4         5         6         7
# 3rd line         8         9        10        11
# 4th line        12        13        14        15
# 5th line        16        17        18        19

# %%
df.loc[:, "column A"]
# Out:
# 1st line     0
# 2nd line     4
# 3rd line     8
# 4th line    12
# 5th line    16
# Name: column A, dtype: int64

# %%
df.loc[:, ["column A", "column C"]]
# Out:
#           column A  column C
# 1st line         0         2
# 2nd line         4         6
# 3rd line         8        10
# 4th line        12        14
# 5th line        16        18

# %%
df.loc["3rd line", :]
# Out:
# column A     8
# column B     9
# column C    10
# Column D    11
# Name: 3rd line, dtype: int64

# %%
df.loc[["2nd line", "4th line"], :]
# Out:
#           column A  column B  column C  Column D
# 2nd line         4         5         6         7
# 4th line        12        13        14        15

# %%
df.loc[["2nd line", "5th line"], ["column B", "Column D"]]
# Out:
#           column B  Column D
# 2nd line         5         7
# 5th line        17        19

# %%
df.iloc[0, 2]
# Out:
# 2

# %%
df.iloc[2:, 3]
# Out:
# 3rd line    11
# 4th line    15
# 5th line    19
# Name: Column D, dtype: int64

# %%
df.iloc[1:, :2]
# Out:
#           column A  column B
# 2nd line         4         5
# 3rd line         8         9
# 4th line        12        13
# 5th line        16        17
